# %%
import os
import pandas as pd
import datetime as dt

# to print all the outputs in the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import helpers

# %%
source_dir = './data/processed/'

# files to download:
file_users = 'users_processed.csv'

# %%
df = pd.read_csv(os.path.join(source_dir, file_users), usecols = ['session_start_ts'], parse_dates=['session_start_ts'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373880 entries, 0 to 373879
# Data columns (total 1 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   session_start_ts  373880 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.9 MB

# %%
start_date = df['session_start_ts'].dt.date.min()
end_date = df['session_start_ts'].dt.date.max()

# %%
df = helpers.create_calendar_table(start_date, end_date)
df
# Out:
#           date  week_num week_start_monday    week_end      year_week
# 0   2017-06-01        22        2017-05-29  2017-06-04  2017, Week 22  \
# 1   2017-06-02        22        2017-05-29  2017-06-04  2017, Week 22
# 2   2017-06-03        22        2017-05-29  2017-06-04  2017, Week 22
# 3   2017-06-04        22        2017-05-29  2017-06-04  2017, Week 22
# 4   2017-06-05        23        2017-06-05  2017-06-11  2017, Week 23
# ..         ...       ...               ...         ...            ...
# 360 2018-05-27        21        2018-05-21  2018-05-27  2018, Week 21
# 361 2018-05-28        22        2018-05-28  2018-06-03  2018, Week 22
# 362 2018-05-29        22        2018-05-28  2018-06-03  2018, Week 22
# 363 2018-05-30        22        2018-05-28  2018-06-03  2018, Week 22
# 364 2018-05-31        22        2018-05-28  2018-06-03  2018, Week 22
#
#                                  week_range    weekday abbreviated_weekday
# ...

# %%
path_to_save = './data/processed/'
file_calendar_tbl = 'calendar_tbl.csv'

# %%
df.to_csv(os.path.join(path_to_save, file_calendar_tbl), sep=',', encoding='utf-8', index=False)
